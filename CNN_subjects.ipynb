# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/C247Project/project/
# Out:
# /content/drive/.shortcut-targets-by-id/1lO_lCKfnzu9fB3MDutIRFUOktcz9B9el/C247Project/project

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.5)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 2.6 MB/s
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109

# %%
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Permute, Bidirectional, BatchNormalization, Conv2D, LSTM, Dense, Dropout, ELU, Flatten, MaxPool2D, TimeDistributed, Dense
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.initializers import lecun_uniform
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()

if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')

# %% [markdown]
# ## Import Datasets

# %%
X_test = np.load("Dataset/X_test.npy")
y_test = np.load("Dataset/y_test.npy")
X_train_valid = np.load("Dataset/X_train_valid.npy")
y_train_valid = np.load("Dataset/y_train_valid.npy")
person_train_valid = np.load("Dataset/person_train_valid.npy")
person_test = np.load("Dataset/person_test.npy")

## Adjusting the labels 
y_train_valid -= 769
y_test -= 769

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %% [markdown]
# ## Function Definitions

# %%
def data_prep(X,y,sub_sample,average,noise):
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]

    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    total_X, total_y = X_max, y
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    
    # Subsampling
    for i in range(sub_sample):
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
    
    return total_X,total_y


def rand_split_reshape_data(X_train_valid_prep, y_train_valid_prep, X_test_prep, y_test_prep, valid_size=1500):
    # First generating the training and validation indices using random splitting
    ind_valid = np.random.choice(len(X_train_valid_prep), len(X_train_valid_prep)//8, replace=False)
    ind_train = np.array(list(set(range(len(X_train_valid_prep))).difference(set(ind_valid))))

    # Creating the training and validation sets using the generated indices
    (x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid]
    (y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]

    # Converting the labels to categorical variables for multiclass classification
    y_train = to_categorical(y_train, 4)
    y_valid = to_categorical(y_valid, 4)
    y_test = to_categorical(y_test_prep, 4)

    # Adding width of the segment to be 1
    x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
    x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
    x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)

    # Reshaping the training and validation dataset
    x_train = np.swapaxes(x_train, 1,3)
    x_train = np.swapaxes(x_train, 1,2)
    x_valid = np.swapaxes(x_valid, 1,3)
    x_valid = np.swapaxes(x_valid, 1,2)
    x_test = np.swapaxes(x_test, 1,3)
    x_test = np.swapaxes(x_test, 1,2)

    return x_train, y_train, x_valid, y_valid, x_test, y_test
    

def rand_split_data(X_train_valid_prep, y_train_valid_prep, X_test_prep, y_test_prep, valid_size=1500):
    # First generating the training and validation indices using random splitting
    ind_valid = np.random.choice(len(X_train_valid_prep), valid_size, replace=False)
    ind_train = np.array(list(set(range(len(X_train_valid_prep))).difference(set(ind_valid))))

    # Creating the training and validation sets using the generated indices
    (x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid]
    (y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]

    return x_train, y_train, x_valid, y_valid, X_test_prep, y_test_prep


def convert_categorical(x_train, y_train, x_valid, y_valid, X_test_prep, y_test):
    # Converting the labels to categorical variables for multiclass classification
    y_train = to_categorical(y_train, 4)
    y_valid = to_categorical(y_valid, 4)
    y_test = to_categorical(y_test, 4)
    return x_train, y_train, x_valid, y_valid, X_test_prep, y_test


def reshape_data(x_train, y_train, x_valid, y_valid, x_test, y_test): 
    # Adding width of the segment to be 1
    x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
    x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
    x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)

    # Reshaping the training and validation dataset
    x_train = np.swapaxes(x_train, 1,3)
    x_train = np.swapaxes(x_train, 1,2)
    x_valid = np.swapaxes(x_valid, 1,3)
    x_valid = np.swapaxes(x_valid, 1,2)
    x_test = np.swapaxes(x_test, 1,3)
    x_test = np.swapaxes(x_test, 1,2)

    return x_train, y_train, x_valid, y_valid, x_test, y_test


def sub_selection(idx, X_train, y_train, X_test, y_test, person_train_valid, person_test):
    train_idx = np.where(person_train_valid == idx)[0]
    test_idx = np.where(person_test == idx)[0]
    X_train = X_train[train_idx]
    y_train = y_train[train_idx]
    X_test = X_test[test_idx]
    y_test = y_test[test_idx]
    return X_train, y_train, X_test, y_test


def train(model, params, data, idx=None):
    epoch_num, batch_size = params
    X_train_valid, y_train_valid, X_test, y_test, person_train_valid, person_test = data

    # Subject split
    if idx is not None:
        X_train_valid, y_train_valid, X_test, y_test = sub_selection(idx, X_train_valid, y_train_valid, X_test, y_test, person_train_valid, person_test)

    # Preprocess Data: Training and testing data
    X_train_valid_prep, y_train_valid_prep = data_prep(X_train_valid,y_train_valid,2,2,True)
    X_test_prep, y_test_prep = data_prep(X_test,y_test,2,2,True)

    # Randomly split and reshape: Training Data 
    x_train, y_train, x_valid, y_valid, x_test, y_test = rand_split_reshape_data(X_train_valid_prep, y_train_valid_prep, X_test_prep, y_test_prep)

    model.fit(x_train, y_train, epochs=epoch_num, batch_size=batch_size, 
              validation_data=(x_valid, y_valid), shuffle=True, verbose=1)
    train_score = model.evaluate(x_train, y_train)
    test_score = model.evaluate(x_test, y_test)

    print('train {:s}: {:.3f}%'.format(model.metrics_names[1], train_score[1]*100))
    print('test {:s}: {:.3f}%'.format(model.metrics_names[1], test_score[1]*100))
    
    return train_score, test_score

def train_split_first(model, params, data, idx=None):
    epoch_num, batch_size = params
    X_train_valid, y_train_valid, X_test, y_test, person_train_valid, person_test = data

    # Subject split
    if idx is not None:
        X_train_valid, y_train_valid, X_test, y_test = sub_selection(idx, X_train_valid, y_train_valid, X_test, y_test, person_train_valid, person_test)
    
    train_valid_size = len(X_train_valid)
    valid_size = int(train_valid_size * 0.17)

    # Randomly split: Training Data 
    x_train, y_train, x_valid, y_valid, x_test, y_test = rand_split_data(X_train_valid, y_train_valid, X_test, y_test, valid_size)

    # Preprocess: Training, validation, and testing data
    x_train, y_train = data_prep(x_train,y_train,2,2,True)
    x_valid, y_valid = data_prep(x_valid, y_valid,2,2,True)
    x_test, y_test = data_prep(x_test, y_test,2,2,True)

    # Cnvert labels into categorical
    x_train, y_train, x_valid, y_valid, x_test, y_test = convert_categorical(x_train, y_train, x_valid, y_valid, x_test, y_test)

    # Reshape: Training, validation, and testing data
    x_train, y_train, x_valid, y_valid, x_test, y_test = reshape_data(x_train, y_train, x_valid, y_valid, x_test, y_test)

    model.fit(x_train, y_train, epochs=epoch_num, batch_size=batch_size, 
              validation_data=(x_valid, y_valid), shuffle=True, verbose=1)
    train_score = model.evaluate(x_train, y_train)
    test_score = model.evaluate(x_test, y_test)

    print('train {:s}: {:.3f}%'.format(model.metrics_names[1], train_score[1]*100))
    print('test {:s}: {:.3f}%'.format(model.metrics_names[1], test_score[1]*100))
    
    return train_score, test_score

# %% [markdown]
# ## CNN model setup

# %%
def CNN_model1(kernel_initializer, params):

    lr, dropout_rate = params

    channels_in_1, channels_out_1, kernel_size_1, stride_1 = (250,1,22), 25, (10, 1), 1
    pool_size_1, pool_stride_1 = (3, 1), 1
    channels_out_2, kernel_size_2, stride_2 = 50, (10, 1), 1
    pool_size_2, pool_stride_2 = (3, 1), 1
    channels_out_3, kernel_size_3, stride_3 = 100, (10, 1), 1
    pool_size_3, pool_stride_3 = (3, 1), 1
    channels_out_4, kernel_size_4, stride_4 = 200, (10, 1), 1
    pool_size_4, pool_stride_4 = (3, 1), 1
    hiddendim_1, hiddendim_2, hiddendim_3 = 100, 50, 25

    model = Sequential(
        [
        Conv2D(filters=channels_out_1, kernel_size=kernel_size_1, padding='same', activation='elu', input_shape=channels_in_1),
        MaxPool2D(pool_size=pool_size_1, padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),

        Conv2D(filters=channels_out_2, kernel_size=kernel_size_2, padding='same', activation='elu'),
        MaxPool2D(pool_size=pool_size_2, padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),

        Conv2D(filters=channels_out_3, kernel_size=kernel_size_3, padding='same', activation='elu'),
        MaxPool2D(pool_size=pool_size_3, padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),

        Conv2D(filters=channels_out_4, kernel_size=kernel_size_4, padding='same', activation='elu'),
        MaxPool2D(pool_size=pool_size_4, padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),
         
        Flatten(),
        Dense(num_classes, activation='softmax'),
        ]
    )
    model.compile(loss='categorical_crossentropy', 
                  optimizer=Adam(learning_rate=lr),
                  metrics=[categorical_accuracy])
    return model


def CNN_model2(kernel_initializer, params):
    lr = params
    model = Sequential(
        [
        Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', input_shape=(250,1,22)),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(0.5),

        Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu'),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(0.5),

        Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(0.5),

        Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu'),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(0.5),
         
        Flatten(),
        Dense(4, activation='softmax'),
        ]
    )
    model.compile(loss='categorical_crossentropy', 
                  optimizer=Adam(learning_rate=lr),
                  metrics=[categorical_accuracy])
    return model

def CNN_model3(kernel_initializer, params):
    lr, dropout_rate, regularizer = params
    model = Sequential(
        [
        Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', 
               kernel_regularizer=regularizer, input_shape=(250,1,22)),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),

        Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu', 
               kernel_regularizer=regularizer),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),

        Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu',
               kernel_regularizer=regularizer),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),

        Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu', 
               kernel_regularizer=regularizer),
        MaxPool2D(pool_size=(3,1), padding='same'),
        BatchNormalization(),
        Dropout(dropout_rate),
         
        Flatten(),
         

        Dense(4, activation='softmax'),
        ]
    )
    model.compile(loss='categorical_crossentropy', 
                optimizer=Adam(learning_rate=lr),
                metrics=[categorical_accuracy])
    return model

# %% [markdown]
# ## CNN Hyper parameter tuning

# %%
batch_size = 60
drop_out = 0.2
learning_rate = 1e-3
epoch_num = 30
num_classes = 4

# %%
learning_rates = [1e-4, 5e-4, 1e-3]
dropout_rates = [0.2, 0.3, 0.4]
batch_sizes = [60,65]
opt_rs = []  
for i in range(9):
  accuracies = []
  for learning_rate in learning_rates:
    for dropout_rate in dropout_rates:
      for batch_size in batch_sizes:
        cnn_model = CNN_model1(lecun_uniform(seed=42), [learning_rate, drop_out])
        train_score, test_score = train(cnn_model, 
                                      [epoch_num, batch_size],
                                      [X_train_valid, y_train_valid, X_test, y_test, person_train_valid, person_test], idx = i
                                      )
        accuracies.append((i, learning_rate,dropout_rate, batch_size, test_score[1]*100))
  # print(accuracies)
  sort = sorted(accuracies, key = lambda x : x[4])
  opt_rs.append(sort[-1])
print(opt_rs)
# Out:
# Streaming output truncated to the last 5000 lines.
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0131 - categorical_accuracy: 0.9988 - val_loss: 0.2925 - val_categorical_accuracy: 0.9658
# Epoch 30/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0100 - categorical_accuracy: 0.9976 - val_loss: 0.2378 - val_categorical_accuracy: 0.9658
# 26/26 [==============================] - 0s 5ms/step - loss: 2.6758e-04 - categorical_accuracy: 1.0000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.
- val_categorical_accuracy: 1.0000
# Epoch 24/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0086 - categorical_accuracy: 0.9976 - val_loss: 5.6356e-04 - val_categorical_accuracy: 1.0000
# Epoch 25/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0037 - categorical_accuracy: 1.0000 - val_loss: 5.3953e-04 - val_categorical_accuracy: 1.0000
# Epoch 26/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0037 - categorical_accuracy: 1.0000 - val_loss: 3.4875e-04 - val_categorical_accuracy: 1.0000
# Epoch 27/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0044 - categorical_accuracy: 0.9988 - val_loss: 3.5943e-04 - val_categorical_accuracy: 1.0000
# Epoch 28/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0041 - categorical_accuracy: 0.9988 - val_loss: 2.0441e-04 - val_categorical_accuracy: 1.0000
# Epoch 29/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 3.9419e-04 - val_categorical_accuracy: 1.0000
# Epoch 30/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0052 - categorical_accuracy: 1.0000 - val_loss: 7.4888e-04 - val_categorical_accuracy: 1.0000
# 26/26 [==============================] - 0s 6ms/step - loss: 5.3127e-05 - categorical_accuracy: 1.0000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.1951 - categorical_accuracy: 0.7819
# train categorical_accuracy: 100.000%
# test categorical_accuracy: 78.191%
# Epoch 1/30
# 14/14 [==============================] - 2s 34ms/step - loss: 2.0285 - categorical_accuracy: 0.2518 - val_loss: 1.5660 - val_categorical_accuracy: 0.2712
# Epoch 2/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.5602 - categorical_accuracy: 0.3850 - val_loss: 1.1775 - val_categorical_accuracy: 0.4915
# Epoch 3/30
# 14/14 [==============================] - 0s 13ms/step - loss: 1.3571 - categorical_accuracy: 0.4431 - val_loss: 1.2554 - val_categorical_accuracy: 0.3898
# Epoch 4/30
# 14/14 [==============================] - 0s 11ms/step - loss: 1.1780 - categorical_accuracy: 0.4939 - val_loss: 1.1213 - val_categorical_accuracy: 0.4407
# Epoch 5/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0748 - categorical_accuracy: 0.5605 - val_loss: 0.9239 - val_categorical_accuracy: 0.5508
# Epoch 6/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.9167 - categorical_accuracy: 0.6199 - val_loss: 0.8173 - val_categorical_accuracy: 0.6610
# Epoch 7/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.8876 - categorical_accuracy: 0.6513 - val_loss: 0.7851 - val_categorical_accuracy: 0.6525
# Epoch 8/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.8471 - categorical_accuracy: 0.6610 - val_loss: 0.6709 - val_categorical_accuracy: 0.7627
# Epoch 9/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.7800 - categorical_accuracy: 0.6985 - val_loss: 0.6013 - val_categorical_accuracy: 0.7966
# Epoch 10/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6917 - categorical_accuracy: 0.7228 - val_loss: 0.4904 - val_categorical_accuracy: 0.8814
# Epoch 11/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6306 - categorical_accuracy: 0.7409 - val_loss: 0.4823 - val_categorical_accuracy: 0.8644
# Epoch 12/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6006 - categorical_accuracy: 0.7833 - val_loss: 0.4128 - val_categorical_accuracy: 0.8898
# Epoch 13/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5346 - categorical_accuracy: 0.7918 - val_loss: 0.3576 - val_categorical_accuracy: 0.9237
# Epoch 14/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4877 - categorical_accuracy: 0.8111 - val_loss: 0.3331 - val_categorical_accuracy: 0.9068
# Epoch 15/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4603 - categorical_accuracy: 0.8281 - val_loss: 0.2896 - val_categorical_accuracy: 0.9407
# Epoch 16/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4544 - categorical_accuracy: 0.8329 - val_loss: 0.2891 - val_categorical_accuracy: 0.9407
# Epoch 17/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3974 - categorical_accuracy: 0.8584 - val_loss: 0.2484 - val_categorical_accuracy: 0.9492
# Epoch 18/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3670 - categorical_accuracy: 0.8705 - val_loss: 0.2125 - val_categorical_accuracy: 0.9661
# Epoch 19/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3388 - categorical_accuracy: 0.8862 - val_loss: 0.2039 - val_categorical_accuracy: 0.9576
# Epoch 20/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3335 - categorical_accuracy: 0.8886 - val_loss: 0.1795 - val_categorical_accuracy: 0.9831
# Epoch 21/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3119 - categorical_accuracy: 0.8898 - val_loss: 0.1625 - val_categorical_accuracy: 0.9831
# Epoch 22/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3007 - categorical_accuracy: 0.8898 - val_loss: 0.1608 - val_categorical_accuracy: 0.9746
# Epoch 23/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2636 - categorical_accuracy: 0.9104 - val_loss: 0.1441 - val_categorical_accuracy: 0.9831
# Epoch 24/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2383 - categorical_accuracy: 0.9334 - val_loss: 0.1327 - val_categorical_accuracy: 0.9831
# Epoch 25/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2457 - categorical_accuracy: 0.9298 - val_loss: 0.1246 - val_categorical_accuracy: 0.9831
# Epoch 26/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2211 - categorical_accuracy: 0.9370 - val_loss: 0.1062 - val_categorical_accuracy: 0.9915
# Epoch 27/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2118 - categorical_accuracy: 0.9395 - val_loss: 0.0948 - val_categorical_accuracy: 1.0000
# Epoch 28/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1920 - categorical_accuracy: 0.9383 - val_loss: 0.0905 - val_categorical_accuracy: 1.0000
# Epoch 29/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1930 - categorical_accuracy: 0.9358 - val_loss: 0.0848 - val_categorical_accuracy: 0.9915
# Epoch 30/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1773 - categorical_accuracy: 0.9504 - val_loss: 0.0822 - val_categorical_accuracy: 0.9915
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0327 - categorical_accuracy: 1.0000
# 7/7 [==============================] - 0s 20ms/step - loss: 1.4890 - categorical_accuracy: 0.4694
# train categorical_accuracy: 100.000%
# test categorical_accuracy: 46.939%
# Epoch 1/30
# 13/13 [==============================] - 1s 36ms/step - loss: 1.9511 - categorical_accuracy: 0.2591 - val_loss: 1.5962 - val_categorical_accuracy: 0.3305
# Epoch 2/30
# 13/13 [==============================] - 0s 15ms/step - loss: 1.5322 - categorical_accuracy: 0.3838 - val_loss: 1.3046 - val_categorical_accuracy: 0.4237
# Epoch 3/30
# 13/13 [==============================] - 0s 13ms/step - loss: 1.2807 - categorical_accuracy: 0.4697 - val_loss: 1.2643 - val_categorical_accuracy: 0.4746
# Epoch 4/30
# 13/13 [==============================] - 0s 14ms/step - loss: 1.1768 - categorical_accuracy: 0.5194 - val_loss: 1.1610 - val_categorical_accuracy: 0.5000
# Epoch 5/30
# 13/13 [==============================] - 0s 14ms/step - loss: 1.0721 - categorical_accuracy: 0.5605 - val_loss: 1.0200 - val_categorical_accuracy: 0.5593
# Epoch 6/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.9771 - categorical_accuracy: 0.5908 - val_loss: 0.9546 - val_categorical_accuracy: 0.5847
# Epoch 7/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.8851 - categorical_accuracy: 0.6501 - val_loss: 0.8768 - val_categorical_accuracy: 0.6186
# Epoch 8/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.8214 - categorical_accuracy: 0.6780 - val_loss: 0.7275 - val_categorical_accuracy: 0.6780
# Epoch 9/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.7268 - categorical_accuracy: 0.7288 - val_loss: 0.6261 - val_categorical_accuracy: 0.7797
# Epoch 10/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.6802 - categorical_accuracy: 0.7458 - val_loss: 0.5577 - val_categorical_accuracy: 0.7797
# Epoch 11/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.5997 - categorical_accuracy: 0.7736 - val_loss: 0.4669 - val_categorical_accuracy: 0.8644
# Epoch 12/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5403 - categorical_accuracy: 0.8027 - val_loss: 0.4089 - val_categorical_accuracy: 0.9237
# Epoch 13/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.5645 - categorical_accuracy: 0.7990 - val_loss: 0.3706 - val_categorical_accuracy: 0.9068
# Epoch 14/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5059 - categorical_accuracy: 0.8027 - val_loss: 0.3184 - val_categorical_accuracy: 0.9407
# Epoch 15/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4432 - categorical_accuracy: 0.8450 - val_loss: 0.2763 - val_categorical_accuracy: 0.9492
# Epoch 16/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4098 - categorical_accuracy: 0.8547 - val_loss: 0.2429 - val_categorical_accuracy: 0.9576
# Epoch 17/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4313 - categorical_accuracy: 0.8366 - val_loss: 0.2142 - val_categorical_accuracy: 0.9831
# Epoch 18/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.4012 - categorical_accuracy: 0.8608 - val_loss: 0.1901 - val_categorical_accuracy: 0.9831
# Epoch 19/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3456 - categorical_accuracy: 0.8850 - val_loss: 0.1689 - val_categorical_accuracy: 0.9831
# Epoch 20/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3164 - categorical_accuracy: 0.9019 - val_loss: 0.1551 - val_categorical_accuracy: 1.0000
# Epoch 21/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3107 - categorical_accuracy: 0.8910 - val_loss: 0.1273 - val_categorical_accuracy: 1.0000
# Epoch 22/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2816 - categorical_accuracy: 0.9044 - val_loss: 0.1119 - val_categorical_accuracy: 1.0000
# Epoch 23/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2810 - categorical_accuracy: 0.9128 - val_loss: 0.1000 - val_categorical_accuracy: 1.0000
# Epoch 24/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2345 - categorical_accuracy: 0.9262 - val_loss: 0.0919 - val_categorical_accuracy: 1.0000
# Epoch 25/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2415 - categorical_accuracy: 0.9140 - val_loss: 0.0910 - val_categorical_accuracy: 1.0000
# Epoch 26/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2290 - categorical_accuracy: 0.9237 - val_loss: 0.0780 - val_categorical_accuracy: 1.0000
# Epoch 27/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2140 - categorical_accuracy: 0.9370 - val_loss: 0.0718 - val_categorical_accuracy: 1.0000
# Epoch 28/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1780 - categorical_accuracy: 0.9479 - val_loss: 0.0613 - val_categorical_accuracy: 1.0000
# Epoch 29/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1747 - categorical_accuracy: 0.9516 - val_loss: 0.0613 - val_categorical_accuracy: 1.0000
# Epoch 30/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1643 - categorical_accuracy: 0.9552 - val_loss: 0.0513 - val_categorical_accuracy: 1.0000
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0251 - categorical_accuracy: 1.0000
# 7/7 [==============================] - 0s 8ms/step - loss: 1.9457 - categorical_accuracy: 0.3724
# train categorical_accuracy: 100.000%
# test categorical_accuracy: 37.245%
# Epoch 1/30
# 14/14 [==============================] - 1s 31ms/step - loss: 1.9544 - categorical_accuracy: 0.2772 - val_loss: 1.9066 - val_categorical_accuracy: 0.3220
# Epoch 2/30
# 14/14 [==============================] - 0s 13ms/step - loss: 1.4866 - categorical_accuracy: 0.4395 - val_loss: 1.5575 - val_categorical_accuracy: 0.4068
# Epoch 3/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.3056 - categorical_accuracy: 0.4891 - val_loss: 1.4682 - val_categorical_accuracy: 0.4068
# Epoch 4/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.1482 - categorical_accuracy: 0.5327 - val_loss: 1.2330 - val_categorical_accuracy: 0.4661
# Epoch 5/30
# 14/14 [==============================] - 0s 12ms/step - loss: 1.0757 - categorical_accuracy: 0.5763 - val_loss: 1.0374 - val_categorical_accuracy: 0.5424
# Epoch 6/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.9070 - categorical_accuracy: 0.6332 - val_loss: 0.9194 - val_categorical_accuracy: 0.6525
# Epoch 7/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.8503 - categorical_accuracy: 0.6501 - val_loss: 0.8028 - val_categorical_accuracy: 0.7373
# Epoch 8/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.8372 - categorical_accuracy: 0.6695 - val_loss: 0.7152 - val_categorical_accuracy: 0.7966
# Epoch 9/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.7376 - categorical_accuracy: 0.6998 - val_loss: 0.5935 - val_categorical_accuracy: 0.8136
# Epoch 10/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6807 - categorical_accuracy: 0.7337 - val_loss: 0.4989 - val_categorical_accuracy: 0.8814
# Epoch 11/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5735 - categorical_accuracy: 0.7833 - val_loss: 0.4429 - val_categorical_accuracy: 0.8644
# Epoch 12/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5555 - categorical_accuracy: 0.7857 - val_loss: 0.3748 - val_categorical_accuracy: 0.9068
# Epoch 13/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4792 - categorical_accuracy: 0.8160 - val_loss: 0.3202 - val_categorical_accuracy: 0.9322
# Epoch 14/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4991 - categorical_accuracy: 0.8196 - val_loss: 0.2981 - val_categorical_accuracy: 0.9237
# Epoch 15/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4360 - categorical_accuracy: 0.8462 - val_loss: 0.2696 - val_categorical_accuracy: 0.9492
# Epoch 16/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4476 - categorical_accuracy: 0.8329 - val_loss: 0.2607 - val_categorical_accuracy: 0.9322
# Epoch 17/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.4034 - categorical_accuracy: 0.8608 - val_loss: 0.2193 - val_categorical_accuracy: 0.9661
# Epoch 18/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3298 - categorical_accuracy: 0.8910 - val_loss: 0.1946 - val_categorical_accuracy: 0.9661
# Epoch 19/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3480 - categorical_accuracy: 0.8838 - val_loss: 0.2045 - val_categorical_accuracy: 0.9492
# Epoch 20/30
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3394 - categorical_accuracy: 0.8814 - val_loss: 0.1966 - val_categorical_accuracy: 0.9492
# Epoch 21/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2969 - categorical_accuracy: 0.8971 - val_loss: 0.1663 - val_categorical_accuracy: 0.9661
# Epoch 22/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2867 - categorical_accuracy: 0.9019 - val_loss: 0.1824 - val_categorical_accuracy: 0.9576
# Epoch 23/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2475 - categorical_accuracy: 0.9225 - val_loss: 0.1557 - val_categorical_accuracy: 0.9576
# Epoch 24/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.2337 - categorical_accuracy: 0.9153 - val_loss: 0.1514 - val_categorical_accuracy: 0.9661
# Epoch 25/30
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2124 - categorical_accuracy: 0.9298 - val_loss: 0.1394 - val_categorical_accuracy: 0.9661
# Epoch 26/30
# 14/14 [==============================] - 0s 15ms/step - loss: 0.2378 - categorical_accuracy: 0.9262 - val_loss: 0.1317 - val_categorical_accuracy: 0.9661
# Epoch 27/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.2164 - categorical_accuracy: 0.9346 - val_loss: 0.1583 - val_categorical_accuracy: 0.9576
# Epoch 28/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1815 - categorical_accuracy: 0.9516 - val_loss: 0.1312 - val_categorical_accuracy: 0.9661
# Epoch 29/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.1774 - categorical_accuracy: 0.9576 - val_loss: 0.1318 - val_categorical_accuracy: 0.9661
# Epoch 30/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1867 - categorical_accuracy: 0.9298 - val_loss: 0.1340 - val_categorical_accuracy: 0.9661
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0366 - categorical_accuracy: 0.9988
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1979 - categorical_accuracy: 0.5204
# ...
# Epoch 3/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1552 - categorical_accuracy: 0.9481 - val_loss: 4.9487 - val_categorical_accuracy: 0.2087
# Epoch 4/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0943 - categorical_accuracy: 0.9679 - val_loss: 2.5240 - val_categorical_accuracy: 0.3913
# Epoch 5/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0628 - categorical_accuracy: 0.9815 - val_loss: 1.9309 - val_categorical_accuracy: 0.4174
# Epoch 6/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0466 - categorical_accuracy: 0.9839 - val_loss: 1.0634 - val_categorical_accuracy: 0.6870
# Epoch 7/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0430 - categorical_accuracy: 0.9827 - val_loss: 0.8253 - val_categorical_accuracy: 0.7391
# Epoch 8/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0215 - categorical_accuracy: 0.9988 - val_loss: 0.5226 - val_categorical_accuracy: 0.7652
# Epoch 9/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0299 - categorical_accuracy: 0.9913 - val_loss: 0.1225 - val_categorical_accuracy: 0.9478
# Epoch 10/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0280 - categorical_accuracy: 0.9926 - val_loss: 0.0595 - val_categorical_accuracy: 0.9826
# Epoch 11/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0130 - categorical_accuracy: 0.9975 - val_loss: 0.0382 - val_categorical_accuracy: 0.9826
# Epoch 12/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0202 - categorical_accuracy: 0.9951 - val_loss: 0.0044 - val_categorical_accuracy: 1.0000
# Epoch 13/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0124 - categorical_accuracy: 0.9938 - val_loss: 0.0028 - val_categorical_accuracy: 1.0000
# Epoch 14/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104 - categorical_accuracy: 0.9988 - val_loss: 0.0023 - val_categorical_accuracy: 1.0000
# Epoch 15/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0113 - categorical_accuracy: 0.9975 - val_loss: 7.4759e-04 - val_categorical_accuracy: 1.0000
# Epoch 16/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0107 - categorical_accuracy: 0.9963 - val_loss: 7.5150e-04 - val_categorical_accuracy: 1.0000
# Epoch 17/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0173 - categorical_accuracy: 0.9988 - val_loss: 3.8674e-04 - val_categorical_accuracy: 1.0000
# Epoch 18/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0073 - categorical_accuracy: 0.9988 - val_loss: 4.7686e-04 - val_categorical_accuracy: 1.0000
# Epoch 19/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0072 - categorical_accuracy: 0.9975 - val_loss: 2.7154e-04 - val_categorical_accuracy: 1.0000
# Epoch 20/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0051 - categorical_accuracy: 1.0000 - val_loss: 5.3826e-04 - val_categorical_accuracy: 1.0000
# Epoch 21/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0116 - categorical_accuracy: 0.9988 - val_loss: 2.4733e-04 - val_categorical_accuracy: 1.0000
# Epoch 22/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0050 - categorical_accuracy: 0.9988 - val_loss: 1.7421e-04 - val_categorical_accuracy: 1.0000
# Epoch 23/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0058 - categorical_accuracy: 0.9988 - val_loss: 2.8532e-04 - val_categorical_accuracy: 1.0000
# Epoch 24/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0041 - categorical_accuracy: 1.0000 - val_loss: 7.0186e-04 - val_categorical_accuracy: 1.0000
# Epoch 25/30
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0033 - categorical_accuracy: 1.0000 - val_loss: 2.4553e-04 - val_categorical_accuracy: 1.0000
# Epoch 26/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0043 - categorical_accuracy: 0.9988 - val_loss: 4.2220e-04 - val_categorical_accuracy: 1.0000
# Epoch 27/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0033 - categorical_accuracy: 0.9988 - val_loss: 1.8115e-04 - val_categorical_accuracy: 1.0000
# Epoch 28/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 6.3815e-05 - val_categorical_accuracy: 1.0000
# Epoch 29/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 4.2150e-05 - val_categorical_accuracy: 1.0000
# Epoch 30/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0024 - categorical_accuracy: 0.9988 - val_loss: 3.3939e-05 - val_categorical_accuracy: 1.0000
# 26/26 [==============================] - 0s 5ms/step - loss: 2.8063e-05 - categorical_accuracy: 1.0000
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1345 - categorical_accuracy: 0.6809
# train categorical_accuracy: 100.000%
# test categorical_accuracy: 68.085%
# Epoch 1/30
# 14/14 [==============================] - 2s 34ms/step - loss: 1.2577 - categorical_accuracy: 0.5698 - val_loss: 5.9227 - val_categorical_accuracy: 0.2087
# Epoch 2/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4186 - categorical_accuracy: 0.8430 - val_loss: 4.5663 - val_categorical_accuracy: 0.2522
# Epoch 3/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2355 - categorical_accuracy: 0.9209 - val_loss: 3.2292 - val_categorical_accuracy: 0.3565
# Epoch 4/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.1318 - categorical_accuracy: 0.9481 - val_loss: 2.1745 - val_categorical_accuracy: 0.3739
# Epoch 5/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0822 - categorical_accuracy: 0.9703 - val_loss: 1.3573 - val_categorical_accuracy: 0.4783
# Epoch 6/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0647 - categorical_accuracy: 0.9765 - val_loss: 0.7610 - val_categorical_accuracy: 0.6609
# Epoch 7/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0360 - categorical_accuracy: 0.9864 - val_loss: 0.4902 - val_categorical_accuracy: 0.7565
# Epoch 8/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0317 - categorical_accuracy: 0.9926 - val_loss: 0.1467 - val_categorical_accuracy: 0.9478
# Epoch 9/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0248 - categorical_accuracy: 0.9926 - val_loss: 0.1327 - val_categorical_accuracy: 0.9391
# Epoch 10/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0231 - categorical_accuracy: 0.9963 - val_loss: 0.0065 - val_categorical_accuracy: 1.0000
# Epoch 11/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0168 - categorical_accuracy: 0.9951 - val_loss: 0.0069 - val_categorical_accuracy: 1.0000
# Epoch 12/30
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0133 - categorical_accuracy: 0.9975 - val_loss: 0.0020 - val_categorical_accuracy: 1.0000
# Epoch 13/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0141 - categorical_accuracy: 0.9963 - val_loss: 0.0010 - val_categorical_accuracy: 1.0000
# Epoch 14/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0181 - categorical_accuracy: 0.9938 - val_loss: 8.9661e-04 - val_categorical_accuracy: 1.0000
# Epoch 15/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0135 - categorical_accuracy: 0.9951 - val_loss: 3.4268e-04 - val_categorical_accuracy: 1.0000
# Epoch 16/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0124 - categorical_accuracy: 0.9975 - val_loss: 2.8326e-04 - val_categorical_accuracy: 1.0000
# Epoch 17/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0063 - categorical_accuracy: 1.0000 - val_loss: 2.5932e-04 - val_categorical_accuracy: 1.0000
# Epoch 18/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 1.5921e-04 - val_categorical_accuracy: 1.0000
# Epoch 19/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0070 - categorical_accuracy: 0.9975 - val_loss: 1.0819e-04 - val_categorical_accuracy: 1.0000
# Epoch 20/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0055 - categorical_accuracy: 0.9988 - val_loss: 1.3505e-04 - val_categorical_accuracy: 1.0000
# Epoch 21/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0041 - categorical_accuracy: 0.9988 - val_loss: 1.2326e-04 - val_categorical_accuracy: 1.0000
# Epoch 22/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0032 - categorical_accuracy: 1.0000 - val_loss: 1.3928e-04 - val_categorical_accuracy: 1.0000
# Epoch 23/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 2.2213e-04 - val_categorical_accuracy: 1.0000
# Epoch 24/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 1.2603e-04 - val_categorical_accuracy: 1.0000
# Epoch 25/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 1.3523e-04 - val_categorical_accuracy: 1.0000
# Epoch 26/30
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0033 - categorical_accuracy: 0.9988 - val_loss: 8.2181e-05 - val_categorical_accuracy: 1.0000
# Epoch 27/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 8.6625e-05 - val_categorical_accuracy: 1.0000
# Epoch 28/30
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0025 - categorical_accuracy: 0.9988 - val_loss: 7.0832e-05 - val_categorical_accuracy: 1.0000
# Epoch 29/30
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0047 - categorical_accuracy: 0.9988 - val_loss: 8.7287e-05 - val_categorical_accuracy: 1.0000
# Epoch 30/30
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0047 - categorical_accuracy: 1.0000 - val_loss: 1.2700e-04 - val_categorical_accuracy: 1.0000
# 26/26 [==============================] - 0s 5ms/step - loss: 1.2606e-04 - categorical_accuracy: 1.0000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3638 - categorical_accuracy: 0.6809
# train categorical_accuracy: 100.000%
# test categorical_accuracy: 68.085%
# Epoch 1/30
# 13/13 [==============================] - 1s 35ms/step - loss: 1.2066 - categorical_accuracy: 0.5674 - val_loss: 11.6533 - val_categorical_accuracy: 0.1826
# Epoch 2/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4361 - categorical_accuracy: 0.8418 - val_loss: 2.6412 - val_categorical_accuracy: 0.3739
# Epoch 3/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1911 - categorical_accuracy: 0.9234 - val_loss: 3.6430 - val_categorical_accuracy: 0.2174
# Epoch 4/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.1103 - categorical_accuracy: 0.9629 - val_loss: 3.4864 - val_categorical_accuracy: 0.2609
# Epoch 5/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0670 - categorical_accuracy: 0.9753 - val_loss: 1.2646 - val_categorical_accuracy: 0.4609
# Epoch 6/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0361 - categorical_accuracy: 0.9926 - val_loss: 1.8020 - val_categorical_accuracy: 0.4609
# Epoch 7/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0321 - categorical_accuracy: 0.9926 - val_loss: 0.6783 - val_categorical_accuracy: 0.7043
# Epoch 8/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0241 - categorical_accuracy: 0.9926 - val_loss: 0.3859 - val_categorical_accuracy: 0.8348
# Epoch 9/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0204 - categorical_accuracy: 0.9963 - val_loss: 0.0501 - val_categorical_accuracy: 0.9826
# Epoch 10/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0282 - categorical_accuracy: 0.9938 - val_loss: 0.0524 - val_categorical_accuracy: 0.9913
# Epoch 11/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0265 - categorical_accuracy: 0.9913 - val_loss: 0.0440 - val_categorical_accuracy: 0.9826
# Epoch 12/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0166 - categorical_accuracy: 0.9963 - val_loss: 0.0131 - val_categorical_accuracy: 0.9913
# Epoch 13/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0159 - categorical_accuracy: 0.9938 - val_loss: 0.0064 - val_categorical_accuracy: 1.0000
# Epoch 14/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0128 - categorical_accuracy: 0.9951 - val_loss: 0.0052 - val_categorical_accuracy: 1.0000
# Epoch 15/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0079 - categorical_accuracy: 1.0000 - val_loss: 0.0012 - val_categorical_accuracy: 1.0000
# Epoch 16/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0064 - categorical_accuracy: 1.0000 - val_loss: 7.3571e-04 - val_categorical_accuracy: 1.0000
# Epoch 17/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0045 - categorical_accuracy: 0.9988 - val_loss: 4.5079e-04 - val_categorical_accuracy: 1.0000
# Epoch 18/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0107 - categorical_accuracy: 0.9963 - val_loss: 4.1564e-04 - val_categorical_accuracy: 1.0000
# Epoch 19/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0054 - categorical_accuracy: 0.9988 - val_loss: 2.6373e-04 - val_categorical_accuracy: 1.0000
# Epoch 20/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0096 - categorical_accuracy: 0.9963 - val_loss: 3.5966e-04 - val_categorical_accuracy: 1.0000
# Epoch 21/30
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0087 - categorical_accuracy: 0.9975 - val_loss: 2.1800e-04 - val_categorical_accuracy: 1.0000
# Epoch 22/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036 - categorical_accuracy: 1.0000 - val_loss: 1.6288e-04 - val_categorical_accuracy: 1.0000
# Epoch 23/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0071 - categorical_accuracy: 0.9963 - val_loss: 6.9809e-05 - val_categorical_accuracy: 1.0000
# Epoch 24/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0033 - categorical_accuracy: 1.0000 - val_loss: 7.9353e-05 - val_categorical_accuracy: 1.0000
# Epoch 25/30
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0099 - categorical_accuracy: 0.9975 - val_loss: 1.6456e-04 - val_categorical_accuracy: 1.0000
# Epoch 26/30
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0062 - categorical_accuracy: 0.9988 - val_loss: 8.9120e-05 - val_categorical_accuracy: 1.0000
# Epoch 27/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 1.4066e-04 - val_categorical_accuracy: 1.0000
# Epoch 28/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 1.4116e-04 - val_categorical_accuracy: 1.0000
# Epoch 29/30
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 1.2101e-04 - val_categorical_accuracy: 1.0000
# Epoch 30/30
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0055 - categorical_accuracy: 0.9988 - val_loss: 5.2428e-05 - val_categorical_accuracy: 1.0000
# 26/26 [==============================] - 0s 6ms/step - loss: 3.1239e-05 - categorical_accuracy: 1.0000
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6073 - categorical_accuracy: 0.6277
# train categorical_accuracy: 100.000%
# test categorical_accuracy: 62.766%
# [(0, 0.0005, 0.4, 65, 68.99999976158142), (1, 0.0005, 0.4, 60, 56.99999928474426), (2, 0.0001, 0.2, 65, 67.5000011920929), (3, 0.0005, 0.3, 60, 70.49999833106995), (4, 0.0005, 0.4, 60, 79.78723645210266), (5, 0.0005, 0.2, 60, 55.10203838348389), (6, 0.0001, 0.2, 65, 75.49999952316284), (7, 0.001, 0.3, 60, 62.99999952316284), (8, 0.0005, 0.2, 60, 73.93617033958435)]
